# %%
import pandas as pd

df = pd.read_csv('zepto.csv')
df.rename(columns={'Category': 'category'}, inplace=True)
df['outOfStock'] = df['outOfStock'].astype(int)  # True→1, False→0
df.to_csv('zepto_fixed.csv', index=False)
